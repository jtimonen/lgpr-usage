# %% [markdown]
# # Analyzing the Orthodont dataset using lgpr
# Here we analyse the `Orthodont` dataset (Pinheiro and Bates, 2000).

# %%
require(lgpr)
require(repr)
require(ggplot2)
require(nlme) # the Orthodont data is in this package
require(lattice)
# Out:
# Loading required package: lgpr
# This is lgpr, version 0.30.4.
# Loading required package: repr
# Loading required package: ggplot2
# Loading required package: nlme
# Loading required package: lattice

# %% [markdown]
# The data consists of orthodontic growth measurements for 11 female and 16 male subjects from age 8 to 14.

# %%
options(repr.plot.width=12, repr.plot.height=9)
plot(Orthodont)
data <- as.data.frame(Orthodont)
data$Sex <- as.numeric(data$Sex)
data$Subject <- as.numeric(data$Subject)
print(head(data))
# Out:
#   distance age Subject Sex
# 1     26.0   8      15   1
# 2     25.0  10      15   1
# 3     29.0  12      15   1
# 4     31.0  14      15   1
# 5     21.5   8       3   1
# 6     22.5  10       3   1
# plot without title

# %% [markdown]
# We fit a model with `Subject`, `Days` and `age` as predictors for `distance`.

# %%
fit <- lgp(distance ~ Subject + age + Sex,
           data = data,
           time_variable = "age",
           id_variable = "Subject",
           iter = 1000,
           chains = 1,
           refresh = 0,
           verbose = TRUE)
# Out:
# * Covariate 'Sex' resolved to type 'categorical'.
#
#  ---------- LGPMODEL SUMMARY ----------
#
#   Model:
#     f = f[(1)](Subject, age) + f[(2)](age) + f[(3)](Sex, age)
#     Response variable: distance
#     Observation model: Gaussian
#   Variable types:
#     - Identifier variable: Subject
#     - Time variable: age
#     - Other categorical variables: Sex
#   Observation model: Gaussian
#
#  ---------- PRIOR SPECIFICATIONS ----------
#
#   alpha_id ~ Student-t(nu=20,mu=0,sigma=1)
#   alpha_age ~ Student-t(nu=20,mu=0,sigma=1)
#   alpha_categAge ~ Student-t(nu=20,mu=0,sigma=1)
#
#   ell_id ~ Log-Normal(0,1)
#   ell_age ~ Log-Normal(0,1)
#   ell_categAge ~ Log-Normal(0,1)
#
#   (sigma_n)^2 ~ Inverse-Gamma(2,1)
#
#
# * Observation model = 1
# * Number of data points = 108
# * Number of model components = 3
# * Number of individuals = 27
# * Additional model info:
#   - C_hat = 0
#   - D = [1,1,0,0,1,0]
#   - F_IS_SAMPLED = 0
#
# * Begin postprocessing.
# * Computing relevances over 500 posterior samples.
#
#
#  ---------- LGPFIT SUMMARY ----------
#
# * Average runtime per chain: 20.71 s (warmup) and 13.48 s (sampling)
# * Largest R-hat value is 1.0133 (sigma_n[1])
# * Used relevance method = f_mean
# * Used selection threshold = 0.95
#
#                      Relevance Selected Prob.
# f[(1)](Subject, age)     0.405     TRUE 1.000
# f[(2)](age)              0.281     TRUE 1.000
# f[(3)](Sex, age)         0.149     TRUE 0.946
# noise                    0.164     TRUE 1.000

# %% [markdown]
# We can study the inferred effects of each covariate.

# %%
options(repr.plot.width=15, repr.plot.height=4) 
plot_components_posterior(fit, nrow = 1, ncol = 4, font_size = 14)
# Out:
# plot without title

# %% [markdown]
# We see that the common time effect is quite linearly increasing, and female subjects (Sex=1) seem to have a generally higher growth level. We can visualize the posterior distribution of the sum of all components (red line = mean, ribbon edges = $\pm$ 2 x standard deviation), with the observations (black dots).

# %%
options(repr.plot.width=14, repr.plot.height=10)
plot_posterior_f(fit) + theme(text=element_text(size=18))
# Out:
# plot without title

# %%
# check that Subjects 1-16 are female (Sex=1) and subjects 17-27 are male (Sex=2)
print(data)
# Out:
#     distance age Subject Sex
# 1       26.0   8      15   1
# 2       25.0  10      15   1
# 3       29.0  12      15   1
# 4       31.0  14      15   1
# 5       21.5   8       3   1
# 6       22.5  10       3   1
# 7       23.0  12       3   1
# 8       26.5  14       3   1
# 9       23.0   8       7   1
# 10      22.5  10       7   1
# 11      24.0  12       7   1
# 12      27.5  14       7   1
# 13      25.5   8      14   1
# 14      27.5  10      14   1
# 15      26.5  12      14   1
# 16      27.0  14      14   1
# 17      20.0   8       2   1
# 18      23.5  10       2   1
# 19      22.5  12       2   1
# 20      26.0  14       2   1
# 21      24.5   8      13   1
# 22      25.5  10      13   1
# 23      27.0  12      13   1
# 24      28.5  14      13   1
# 25      22.0   8       5   1
# 26      22.0  10       5   1
# 27      24.5  12       5   1
# 28      26.5  14       5   1
# 29      24.0   8       6   1
# 30      21.5  10       6   1
# 31      24.5  12       6   1
# 32      25.5  14       6   1
# 33      23.0   8      11   1
# 34      20.5  10      11   1
# 35      31.0  12      11   1
# 36      26.0  14      11   1
# 37      27.5   8      16   1
# 38      28.0  10      16   1
# 39      31.0  12      16   1
# 40      31.5  14      16   1
# 41      23.0   8       4   1
# 42      23.0  10       4   1
# 43      23.5  12       4   1
# 44      25.0  14       4   1
# 45      21.5   8       8   1
# 46      23.5  10       8   1
# 47      24.0  12       8   1
# 48      28.0  14       8   1
# 49      17.0   8       9   1
# 50      24.5  10       9   1
# 51      26.0  12       9   1
# 52      29.5  14       9   1
# 53      22.5   8      10   1
# 54      25.5  10      10   1
# 55      25.5  12      10   1
# 56      26.0  14      10   1
# 57      23.0   8      12   1
# 58      24.5  10      12   1
# 59      26.0  12      12   1
# 60      30.0  14      12   1
# 61      22.0   8       1   1
# 62      21.5  10       1   1
# 63      23.5  12       1   1
# 64      25.0  14       1   1
# 65      21.0   8      20   2
# 66      20.0  10      20   2
# 67      21.5  12      20   2
# 68      23.0  14      20   2
# 69      21.0   8      23   2
# 70      21.5  10      23   2
# 71      24.0  12      23   2
# 72      25.5  14      23   2
# 73      20.5   8      25   2
# 74      24.0  10      25   2
# 75      24.5  12      25   2
# 76      26.0  14      25   2
# 77      23.5   8      26   2
# 78      24.5  10      26   2
# 79      25.0  12      26   2
# 80      26.5  14      26   2
# 81      21.5   8      21   2
# 82      23.0  10      21   2
# 83      22.5  12      21   2
# 84      23.5  14      21   2
# 85      20.0   8      19   2
# 86      21.0  10      19   2
# 87      21.0  12      19   2
# 88      22.5  14      19   2
# 89      21.5   8      22   2
# 90      22.5  10      22   2
# 91      23.0  12      22   2
# 92      25.0  14      22   2
# 93      23.0   8      24   2
# 94      23.0  10      24   2
# 95      23.5  12      24   2
# 96      24.0  14      24   2
# 97      20.0   8      18   2
# 98      21.0  10      18   2
# 99      22.0  12      18   2
# 100     21.5  14      18   2
# 101     16.5   8      17   2
# 102     19.0  10      17   2
# 103     19.0  12      17   2
# 104     19.5  14      17   2
# 105     24.5   8      27   2
# 106     25.0  10      27   2
# 107     28.0  12      27   2
# 108     28.0  14      27   2

# %% [markdown]
# ## References
# Pinheiro, J.C. and Bates, D. (2000). *Mixed-Effects Models in S and S-PLUS*. Springer, New York.
